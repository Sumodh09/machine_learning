# %% [markdown]
# # DATA COLLECTION

# %%
import cv2
import mediapipe as mp

mphands = mp.solutions.hands
hands = mphands.Hands()
mp_drawing = mp.solutions.drawing_utils
cap = cv2.VideoCapture(0)
print("########################## Data Collection for ONE Sign ##########################")
_, frame = cap.read()
data = []
h, w, c = frame.shape

while True:
    ret, frame = cap.read()
    framergb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    result = hands.process(framergb)
    hand_landmarks = result.multi_hand_landmarks
    if ret:
        if hand_landmarks:
            for handLMs in hand_landmarks:
                x_max = 0
                y_max = 0
                x_min = w
                y_min = h
                for lm in handLMs.landmark:
                    x, y = int(lm.x * w), int(lm.y * h)
                    if x > x_max:
                        x_max = x
                    if x < x_min:
                        x_min = x
                    if y > y_max:
                        y_max = y
                    if y < y_min:
                        y_min = y
                cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
                mp_drawing.draw_landmarks(frame, handLMs, mphands.HAND_CONNECTIONS)
                face = frame[y_min:y_max,x_min:x_max,:]
            if len(data)<200:
                if face.any():
                    cv2.imshow("Try",face)
                    face = cv2.resize(face,(50,50))
                    print("No of frames collected for ONE Sign: "+str(len(data)))
                    data.append(face)
            else:
                break
            cv2.imshow("Frame", frame)
            cv2.waitKey(1)
cap.release()
# Out:
# ########################## Data Collection for ONE Sign ##########################
# No of frames collected for ONE Sign: 0
# No of frames collected for ONE Sign: 1
# No of frames collected for ONE Sign: 2
# No of frames collected for ONE Sign: 3
# No of frames collected for ONE Sign: 4
# No of frames collected for ONE Sign: 5
# No of frames collected for ONE Sign: 6
# No of frames collected for ONE Sign: 7
# No of frames collected for ONE Sign: 8
# No of frames collected for ONE Sign: 9
# No of frames collected for ONE Sign: 10
# No of frames collected for ONE Sign: 11
# No of frames collected for ONE Sign: 12
# No of frames collected for ONE Sign: 13
# No of frames collected for ONE Sign: 14
# No of frames collected for ONE Sign: 15
# No of frames collected for ONE Sign: 16
# No of frames collected for ONE Sign: 17
# No of frames collected for ONE Sign: 18
# No of frames collected for ONE Sign: 19
# No of frames collected for ONE Sign: 20
# No of frames collected for ONE Sign: 21
# ...

# %%
import numpy as np
np.save("one.npy",data)

# %%
import matplotlib.pyplot as plt
plt.imshow(data[180])

# %%
import cv2
import mediapipe as mp

mphands = mp.solutions.hands
hands = mphands.Hands()
mp_drawing = mp.solutions.drawing_utils
cap = cv2.VideoCapture(0)
print("########################## Data Collection for TWO Sign ##########################")
_, frame = cap.read()
data1 = []
h, w, c = frame.shape

while True:
    ret, frame = cap.read()
    framergb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    result = hands.process(framergb)
    hand_landmarks = result.multi_hand_landmarks
    if ret:
        if hand_landmarks:
            for handLMs in hand_landmarks:
                x_max = 0
                y_max = 0
                x_min = w
                y_min = h
                for lm in handLMs.landmark:
                    x, y = int(lm.x * w), int(lm.y * h)
                    if x > x_max:
                        x_max = x
                    if x < x_min:
                        x_min = x
                    if y > y_max:
                        y_max = y
                    if y < y_min:
                        y_min = y
                cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
                mp_drawing.draw_landmarks(frame, handLMs, mphands.HAND_CONNECTIONS)
                face = frame[y_min:y_max,x_min:x_max,:]
            if len(data1)<200:
                if face.any():
                    cv2.imshow("Try",face)
                    face = cv2.resize(face,(50,50))
                    print("No of frames collected for Two Sign: "+str(len(data1)))
                    data1.append(face)
            else:
                break
            cv2.imshow("Frame", frame)
            cv2.waitKey(1)
cap.release()
# Out:
# ########################## Data Collection for TWO Sign ##########################
# No of frames collected for Two Sign: 0
# No of frames collected for Two Sign: 1
# No of frames collected for Two Sign: 2
# No of frames collected for Two Sign: 3
# No of frames collected for Two Sign: 4
# No of frames collected for Two Sign: 5
# No of frames collected for Two Sign: 6
# No of frames collected for Two Sign: 7
# No of frames collected for Two Sign: 8
# No of frames collected for Two Sign: 9
# No of frames collected for Two Sign: 10
# No of frames collected for Two Sign: 11
# No of frames collected for Two Sign: 12
# No of frames collected for Two Sign: 13
# No of frames collected for Two Sign: 14
# No of frames collected for Two Sign: 15
# No of frames collected for Two Sign: 16
# No of frames collected for Two Sign: 17
# No of frames collected for Two Sign: 18
# No of frames collected for Two Sign: 19
# No of frames collected for Two Sign: 20
# No of frames collected for Two Sign: 21
# ...

# %%
import numpy as np
np.save("two.npy",data1)

# %%
import cv2
import mediapipe as mp

mphands = mp.solutions.hands
hands = mphands.Hands()
mp_drawing = mp.solutions.drawing_utils
cap = cv2.VideoCapture(0)
print("########################## Data Collection for THREE Sign ##########################")
_, frame = cap.read()
data2 = []
h, w, c = frame.shape

while True:
    ret, frame = cap.read()
    framergb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    result = hands.process(framergb)
    hand_landmarks = result.multi_hand_landmarks
    if ret:
        if hand_landmarks:
            for handLMs in hand_landmarks:
                x_max = 0
                y_max = 0
                x_min = w
                y_min = h
                for lm in handLMs.landmark:
                    x, y = int(lm.x * w), int(lm.y * h)
                    if x > x_max:
                        x_max = x
                    if x < x_min:
                        x_min = x
                    if y > y_max:
                        y_max = y
                    if y < y_min:
                        y_min = y
                cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
                mp_drawing.draw_landmarks(frame, handLMs, mphands.HAND_CONNECTIONS)
                face = frame[y_min:y_max,x_min:x_max,:]
            if len(data2)<200:
                if face.any():
                    cv2.imshow("Try",face)
                    face = cv2.resize(face,(50,50))
                    print("No of frames collected for Three Sign: "+str(len(data2)))
                    data2.append(face)
            else:
                break
            cv2.imshow("Frame", frame)
            cv2.waitKey(1)
cap.release()
# Out:
# ########################## Data Collection for THREE Sign ##########################
# No of frames collected for Three Sign: 0
# No of frames collected for Three Sign: 1
# No of frames collected for Three Sign: 2
# No of frames collected for Three Sign: 3
# No of frames collected for Three Sign: 4
# No of frames collected for Three Sign: 5
# No of frames collected for Three Sign: 6
# No of frames collected for Three Sign: 7
# No of frames collected for Three Sign: 8
# No of frames collected for Three Sign: 9
# No of frames collected for Three Sign: 10
# No of frames collected for Three Sign: 11
# No of frames collected for Three Sign: 12
# No of frames collected for Three Sign: 13
# No of frames collected for Three Sign: 14
# No of frames collected for Three Sign: 15
# No of frames collected for Three Sign: 16
# No of frames collected for Three Sign: 17
# No of frames collected for Three Sign: 18
# No of frames collected for Three Sign: 19
# ...

# %%
import numpy as np
np.save("three.npy",data2)

# %%
import cv2
import mediapipe as mp

mphands = mp.solutions.hands
hands = mphands.Hands()
mp_drawing = mp.solutions.drawing_utils
cap = cv2.VideoCapture(0)
print("########################## Data Collection for FOUR Sign ##########################")
_, frame = cap.read()
data3 = []
h, w, c = frame.shape

while True:
    ret, frame = cap.read()
    framergb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    result = hands.process(framergb)
    hand_landmarks = result.multi_hand_landmarks
    if ret:
        if hand_landmarks:
            for handLMs in hand_landmarks:
                x_max = 0
                y_max = 0
                x_min = w
                y_min = h
                for lm in handLMs.landmark:
                    x, y = int(lm.x * w), int(lm.y * h)
                    if x > x_max:
                        x_max = x
                    if x < x_min:
                        x_min = x
                    if y > y_max:
                        y_max = y
                    if y < y_min:
                        y_min = y
                cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
                mp_drawing.draw_landmarks(frame, handLMs, mphands.HAND_CONNECTIONS)
                face = frame[y_min:y_max,x_min:x_max,:]
            if len(data3)<200:
                if face.any():
                    cv2.imshow("Try",face)
                    face = cv2.resize(face,(50,50))
                    print("No of frames collected for Four Sign: "+str(len(data3)))
                    data3.append(face)
            else:
                break
            cv2.imshow("Frame", frame)
            cv2.waitKey(1)
cap.release()
# Out:
# ########################## Data Collection for FOUR Sign ##########################
# No of frames collected for Four Sign: 0
# No of frames collected for Four Sign: 1
# No of frames collected for Four Sign: 2
# No of frames collected for Four Sign: 3
# No of frames collected for Four Sign: 4
# No of frames collected for Four Sign: 5
# No of frames collected for Four Sign: 6
# No of frames collected for Four Sign: 7
# No of frames collected for Four Sign: 8
# No of frames collected for Four Sign: 9
# No of frames collected for Four Sign: 10
# No of frames collected for Four Sign: 11
# No of frames collected for Four Sign: 12
# No of frames collected for Four Sign: 13
# No of frames collected for Four Sign: 14
# No of frames collected for Four Sign: 15
# No of frames collected for Four Sign: 16
# No of frames collected for Four Sign: 17
# No of frames collected for Four Sign: 18
# No of frames collected for Four Sign: 19
# No of frames collected for Four Sign: 20
# ...

# %%
import numpy as np
np.save("four.npy",data3)

# %%
import cv2
import mediapipe as mp

mphands = mp.solutions.hands
hands = mphands.Hands()
mp_drawing = mp.solutions.drawing_utils
cap = cv2.VideoCapture(0)
print("########################## Data Collection for FIVE Sign ##########################")
_, frame = cap.read()
data4 = []
h, w, c = frame.shape

while True:
    ret, frame = cap.read()
    framergb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    result = hands.process(framergb)
    hand_landmarks = result.multi_hand_landmarks
    if ret:
        if hand_landmarks:
            for handLMs in hand_landmarks:
                x_max = 0
                y_max = 0
                x_min = w
                y_min = h
                for lm in handLMs.landmark:
                    x, y = int(lm.x * w), int(lm.y * h)
                    if x > x_max:
                        x_max = x
                    if x < x_min:
                        x_min = x
                    if y > y_max:
                        y_max = y
                    if y < y_min:
                        y_min = y
                cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
                mp_drawing.draw_landmarks(frame, handLMs, mphands.HAND_CONNECTIONS)
                face = frame[y_min:y_max,x_min:x_max,:]
            if len(data4)<200:
                if face.any():
                    cv2.imshow("Try",face)
                    face = cv2.resize(face,(50,50))
                    print("No of frames collected for FIVE Sign: "+str(len(data4)))
                    data4.append(face)
            else:
                break
            cv2.imshow("Frame", frame)
            cv2.waitKey(1)
cap.release()
# Out:
# ########################## Data Collection for FIVE Sign ##########################
# No of frames collected for FIVE Sign: 0
# No of frames collected for FIVE Sign: 1
# No of frames collected for FIVE Sign: 2
# No of frames collected for FIVE Sign: 3
# No of frames collected for FIVE Sign: 4
# No of frames collected for FIVE Sign: 5
# No of frames collected for FIVE Sign: 6
# No of frames collected for FIVE Sign: 7
# No of frames collected for FIVE Sign: 8
# No of frames collected for FIVE Sign: 9
# No of frames collected for FIVE Sign: 10
# No of frames collected for FIVE Sign: 11
# No of frames collected for FIVE Sign: 12
# No of frames collected for FIVE Sign: 13
# No of frames collected for FIVE Sign: 14
# No of frames collected for FIVE Sign: 15
# No of frames collected for FIVE Sign: 16
# No of frames collected for FIVE Sign: 17
# No of frames collected for FIVE Sign: 18
# No of frames collected for FIVE Sign: 19
# No of frames collected for FIVE Sign: 20
# ...

# %%
import numpy as np
np.save("five.npy",data4)

# %%
import matplotlib.pyplot as plt
plt.imshow(data4[50])
